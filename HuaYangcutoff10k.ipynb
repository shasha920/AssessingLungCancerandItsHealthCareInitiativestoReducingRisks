# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("lung_cancer_mortality_data_large_v2.csv")
df
# Out:
#               id   age  gender         country diagnosis_date cancer_stage  \
# 0              1  64.0  Female         Germany     2016-04-07    Stage III
# 1              2  50.0    Male  Czech Republic     2023-04-22    Stage III
# 2              3  65.0    Male         Romania     2023-04-07     Stage IV
# 3              4  51.0  Female          Latvia     2016-02-07    Stage III
# 4              5  37.0    Male          Greece     2023-12-01      Stage I
# ...          ...   ...     ...             ...            ...          ...
# 3249995  3249996  45.0    Male          Poland     2020-03-11     Stage IV
# 3249996  3249997  51.0    Male           Italy     2016-11-16     Stage IV
# 3249997  3249998  45.0    Male         Finland     2021-07-18    Stage III
# 3249998  3249999  45.0    Male         Hungary     2020-07-25      Stage I
# 3249999  3250000  59.0    Male         Croatia     2018-05-12    Stage III
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'gender', 'country', 'diagnosis_date', 'cancer_stage',
#        'beginning_of_treatment_date', 'family_history', 'smoking_status',
#        'bmi', 'cholesterol_level', 'hypertension', 'asthma', 'cirrhosis',
#        'other_cancer', 'treatment_type', 'end_treatment_date', 'survived'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                             0
# age                            0
# gender                         0
# country                        0
# diagnosis_date                 0
# cancer_stage                   0
# beginning_of_treatment_date    0
# family_history                 0
# smoking_status                 0
# bmi                            0
# cholesterol_level              0
# hypertension                   0
# asthma                         0
# cirrhosis                      0
# other_cancer                   0
# treatment_type                 0
# end_treatment_date             0
# survived                       0
# dtype: int64

# %%
df1=df[1:10001]
df1
# Out:
#           id   age  gender         country diagnosis_date cancer_stage  \
# 1          2  50.0    Male  Czech Republic     2023-04-22    Stage III
# 2          3  65.0    Male         Romania     2023-04-07     Stage IV
# 3          4  51.0  Female          Latvia     2016-02-07    Stage III
# 4          5  37.0    Male          Greece     2023-12-01      Stage I
# 5          6  50.0    Male         Finland     2023-01-04     Stage II
# ...      ...   ...     ...             ...            ...          ...
# 9996    9997  61.0  Female        Portugal     2015-10-02      Stage I
# 9997    9998  52.0  Female         Croatia     2022-11-12      Stage I
# 9998    9999  69.0    Male         Estonia     2021-03-25    Stage III
# 9999   10000  70.0    Male     Netherlands     2022-02-11     Stage II
# 10000  10001  73.0  Female          Sweden     2022-03-02      Stage I
#
#       beginning_of_treatment_date family_history  smoking_status   bmi  \
# ...

# %%
df1.to_csv("lung_cancer_data.csv")
